# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasL642/Generative-Adversarial-Networks/blob/main/Peunoima_WGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tqdm
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from glob import glob
import keras

# %%
IMG_SHAPE = (128, 128, 3)
BATCH_SIZE = 100
noise_dim = 64
dir = "" #path goes here
IMG_SIZE = 128

# %%
from tqdm import tqdm
data = []

def create_data():
    path = dir
    for img in tqdm(os.listdir(path)):
      img_array = cv2.imread(os.path.join(path,img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
      data.append(new_array)
    plt.imshow(data[0])
    plt.show()
    print(new_array)

create_data()

train_images = data

print(f"Number of examples:  {len(train_images)}")
print(f"Shape of the images: {np.asarray(train_images).shape[1:]}")

train_images = (np.asarray(train_images).astype(np.float32) - 127.5)/127.5
# Out:
# 100%|██████████| 3875/3875 [25:57<00:00,  2.49it/s]
# [[[13 13 13]
#   [13 13 13]
#   [12 12 12]
#   ...
#   [49 49 49]
#   [47 47 47]
#   [48 48 48]]
#
#  [[13 13 13]
#   [13 13 13]
#   [12 12 12]
#   ...
#   [46 46 46]
#   [45 45 45]
#   [44 44 44]]
#
#  [[11 11 11]
#   [12 12 12]
#   [10 10 10]
#   ...
#   [60 60 60]
#   [49 49 49]
#   [46 46 46]]
#
#  ...
#
#  [[24 24 24]
#   [18 18 18]
#   [21 21 21]
#   ...
#   [24 24 24]
#   [26 26 26]
#   [25 25 25]]
#
#  [[26 26 26]
#   [19 19 19]
#   [17 17 17]
#   ...
#   [21 21 21]
#   [24 24 24]
#   [25 25 25]]
#
#  [[26 26 26]
#   [19 19 19]
#   [17 17 17]
#   ...
#   [21 21 21]
#   [23 23 23]
#   [25 25 25]]]
# Number of examples:  3875
# Shape of the images: (128, 128, 3)

# %%
def conv_l(
    x,
    filters,
    activation,
    kernel_size=(3,3),
    strides=(1,1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5,
):
    x = layers.Conv2D(
        filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias
    )(x)
    if use_bn:
      x =layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
      x = layers.Dropout(drop_value)(x)
    return x

def get_discriminator_model():
  img_input = layers.Input(shape=IMG_SHAPE)
  x = layers.ZeroPadding2D((2, 2))(img_input)
  x = conv_l(
      x,
      64,
      kernel_size = (5,5),
      strides=(2,2),
      use_bn=False,
      use_bias=True,
      activation=layers.LeakyReLU(0.2),
      use_dropout=False,
      drop_value=0.3,
  )
  x = conv_l(
      x,
      128,
      kernel_size = (5,5),
      strides=(2,2),
      use_bn=False,
      activation=layers.LeakyReLU(0.2),
      use_bias=True,
      use_dropout=True,
      drop_value=0.3,
  )
  x = conv_l(
      x,
      256,
      kernel_size = (5,5),
      strides=(2,2),
      use_bn=False,
      activation=layers.LeakyReLU(0.2),
      use_bias=True,
      use_dropout=True,
      drop_value=0.3,
  )
  x = conv_l(
      x,
      512,
      kernel_size = (5,5),
      strides=(2,2),
      use_bn=False,
      activation=layers.LeakyReLU(0.2),
      use_bias=True,
      use_dropout=False,
      drop_value=0.3,
  )
    
  x = layers.Flatten()(x)
  x = layers.Dropout(0.2)(x)
  x = layers.Dense(1)(x)

  d_model = keras.models.Model(img_input, x, name="discriminator")
  return d_model

d_model = get_discriminator_model()
d_model.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 132, 132, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 66, 66, 64)        4864
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 66, 66, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 33, 33, 128)       204928
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 33, 33, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 33, 33, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 17, 17, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 512)         3277312
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41473
# =================================================================
# Total params: 4,348,033
# Trainable params: 4,348,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3,3),
    strides=(1,1),
    up_size=(2,2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3,
):
    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(
        filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias
    )(x)

    if use_bn:
      x = layers.BatchNormalization()(x)

    if activation:
      x = activation(x)
    if use_dropout:
      x = layers.Dropout(drop_value)(x)
    return x

def get_generator_model():
  noise = layers.Input(shape=(noise_dim,))
  x = layers.Dense(4 * 4 * 512, use_bias=False)(noise)
  x = layers.BatchNormalization()(x)
  x = layers.LeakyReLU(0.2)(x)

  x = layers.Reshape((4, 4, 512))(x)
  x = upsample_block(
      x,
      128,
      layers.LeakyReLU(0.2),
      strides=(1, 1),
      use_bias = False,
      use_bn=True,
      padding="same",
      use_dropout=False,
  )
  x = upsample_block(
      x,
      64,
      layers.LeakyReLU(0.2),
      strides=(1,1),
      use_bias=False,
      use_bn=True,
      padding="same",
      use_dropout=False,
  )
  x = upsample_block(
      x,
      32,
      layers.LeakyReLU(0.2),
      strides=(1,1),
      use_bias=False,
      use_bn=True,
      padding="same",
      use_dropout=False,
  )
  x = upsample_block(
      x,
      16,
      layers.LeakyReLU(0.2),
      strides=(1,1),
      use_bias=False,
      use_bn=True,
      padding="same",
      use_dropout=False,
  )
  x = upsample_block(
      x, 3, layers.Activation("tanh"), strides=(1,1), use_bias=False, use_bn=True
  )

  g_model = keras.models.Model(noise, x, name="generator")
  return g_model

g_model = get_generator_model()
g_model.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8192)              524288
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8192)              32768
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8192)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 512)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         589824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        73728
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        18432
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        4608
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 3)       432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128, 128, 3)       12
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 3)       0
# =================================================================
# Total params: 1,245,052
# Trainable params: 1,228,182
# Non-trainable params: 16,870
# _________________________________________________________________

# %%
class WGAN(keras.Model):
  def __init__(
      self,
      discriminator,
      generator,
      latent_dim,
      discriminator_extra_steps=3,
      gp_weight=10.0,

  ):
      super(WGAN, self).__init__()
      self.discriminator = discriminator
      self.generator = generator
      self.latent_dim = latent_dim
      self.d_steps = discriminator_extra_steps
      self.gp_weight = gp_weight
    
  def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
    super(WGAN, self).compile()
    self.d_optimizer = d_optimizer
    self.g_optimizer = g_optimizer
    self.d_loss_fn = d_loss_fn
    self.g_loss_fn = g_loss_fn

  def gradient_penalty(self, batch_size, real_images, fake_images):
    alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
    diff = fake_images - real_images
    interpolated = real_images + alpha * diff

    with tf.GradientTape() as gp_tape:
      gp_tape.watch(interpolated)
      pred = self.discriminator(interpolated, training=True)
      
    grads = gp_tape.gradient(pred, [interpolated])[0]

    norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
    gp = tf.reduce_mean((norm - 1.0) ** 2)
    return gp

  def train_step(self, real_images):
    if isinstance(real_images, tuple):
      real_images = real_images[0]
    batch_size = tf.shape(real_images)[0]

    for i in range(self.d_steps):
      random_latent_vectors = tf.random.normal(
          shape=(batch_size, self.latent_dim)
      )
      with tf.GradientTape() as tape:

        fake_images = self.generator(random_latent_vectors, training=True)

        fake_logits = self.discriminator(fake_images, training=True)
        real_logits = self.discriminator(real_images, training=True)

        d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)

        gp = self.gradient_penalty(batch_size, real_images, fake_images)

        d_loss = d_cost + gp * self.gp_weight

      d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
      self.d_optimizer.apply_gradients(
          zip(d_gradient, self.discriminator.trainable_variables)
      )

      random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
      with tf.GradientTape() as tape:
        generated_images = self.generator(random_latent_vectors, training=True)
        gen_img_logits = self.discriminator(generated_images, training=True)
        g_loss = self.g_loss_fn(gen_img_logits)

      gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
      self.g_optimizer.apply_gradients(
          zip(gen_gradient, self.generator.trainable_variables)
      )

      return {"d_loss": d_loss, "g_loss": g_loss}

# %%
class GANMonitor(keras.callbacks.Callback):
  def __init__(self, num_img=6, latent_dim=128):
    self.num_img = num_img
    self.latent_dim = latent_dim

  def on_epoch_end(self, epoch, logs=None):
    random_latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
    generated_images = self.model.generator(random_latent_vectors)
    generated_images = (generated_images * 127.5) + 127.5

    for i in range(self.num_img):
      img = generated_images[i].numpy()
      img = keras.preprocessing.image.array_to_img(img)
      img.save("generated_img_{i}_{epoch}.png". format(i=i, epoch=epoch))

# %%
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9
)

discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9
)

def discriminator_loss(real_img, fake_img):
  real_loss = tf.reduce_mean(real_img)
  fake_loss = tf.reduce_mean(fake_img)
  return fake_loss - real_loss

def generator_loss(fake_img):
  return -tf.reduce_mean(fake_img)

epochs = 500

cbk = GANMonitor(num_img=3, latent_dim=noise_dim)

wgan = WGAN(
    discriminator= d_model,
    generator = g_model,
    latent_dim = noise_dim,
    discriminator_extra_steps=3,
)

wgan.compile(
    d_optimizer = discriminator_optimizer,
    g_optimizer = generator_optimizer,
    g_loss_fn = generator_loss,
    d_loss_fn = discriminator_loss,
)

wgan.fit(train_images, batch_size=BATCH_SIZE, epochs=epochs, callbacks=[cbk])
# Out:
# Epoch 1/500
# 39/39 [==============================] - 32s 750ms/step - d_loss: -9.3436 - g_loss: 53.6788
# Epoch 2/500
# 39/39 [==============================] - 30s 766ms/step - d_loss: -9.4919 - g_loss: 34.7250
# Epoch 3/500
# 39/39 [==============================] - 30s 782ms/step - d_loss: -8.9463 - g_loss: 23.7863
# Epoch 4/500
# 39/39 [==============================] - 31s 793ms/step - d_loss: -9.4302 - g_loss: 40.7791
# Epoch 5/500
# 39/39 [==============================] - 31s 801ms/step - d_loss: -9.5908 - g_loss: 42.2971
# Epoch 6/500
# 39/39 [==============================] - 32s 809ms/step - d_loss: -9.3204 - g_loss: 60.5910
# Epoch 7/500
# 39/39 [==============================] - 32s 818ms/step - d_loss: -9.6620 - g_loss: 35.6855
# Epoch 8/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.9989 - g_loss: 37.5145
# Epoch 9/500
# 39/39 [==============================] - 32s 820ms/step - d_loss: -8.6613 - g_loss: 32.5413
# Epoch 10/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.6917 - g_loss: 47.4606
# Epoch 11/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -8.0479 - g_loss: 40.6260
# Epoch 12/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -7.7922 - g_loss: 25.9742
# Epoch 13/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -8.0497 - g_loss: 21.3220
# Epoch 14/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.8461 - g_loss: 53.3564
# Epoch 15/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.3654 - g_loss: 35.0998
# Epoch 16/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.1369 - g_loss: 40.9832
# Epoch 17/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.9701 - g_loss: 35.6337
# Epoch 18/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.0993 - g_loss: 33.7325
# Epoch 19/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -7.4755 - g_loss: 30.7607
# Epoch 20/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -8.2690 - g_loss: 26.3810
# Epoch 21/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -8.0251 - g_loss: 11.8622
# Epoch 22/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -7.9981 - g_loss: 19.1651
# Epoch 23/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.7552 - g_loss: 13.5768
# Epoch 24/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.3030 - g_loss: 25.3116
# Epoch 25/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.1950 - g_loss: 16.9859
# Epoch 26/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.1772 - g_loss: 19.3300
# Epoch 27/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -8.3501 - g_loss: 22.4677
# Epoch 28/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.2977 - g_loss: 17.3624
# Epoch 29/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.2221 - g_loss: 10.6877
# Epoch 30/500
# 39/39 [==============================] - 32s 819ms/step - d_loss: -8.0398 - g_loss: 20.6411
# Epoch 31/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -8.3785 - g_loss: 14.3875
# Epoch 32/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -8.3146 - g_loss: 21.2202
# Epoch 33/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -8.2376 - g_loss: 22.5524
# Epoch 34/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -8.1707 - g_loss: 21.2263
# Epoch 35/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -8.4084 - g_loss: 21.8123
# Epoch 36/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -8.2413 - g_loss: 24.5174
# Epoch 37/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -8.3715 - g_loss: 22.5417
# Epoch 38/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.5095 - g_loss: 9.6665
# Epoch 39/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -8.2156 - g_loss: 15.6048
# Epoch 40/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.2272 - g_loss: 22.8483
# Epoch 41/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -8.1110 - g_loss: 24.6316
# Epoch 42/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.4433 - g_loss: 23.0640
# Epoch 43/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -8.0296 - g_loss: 25.7154
# Epoch 44/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.2978 - g_loss: 19.5038
# Epoch 45/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.8340 - g_loss: 21.1480
# Epoch 46/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -8.1326 - g_loss: 28.7669
# Epoch 47/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.8943 - g_loss: 20.4365
# Epoch 48/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.9526 - g_loss: 20.5003
# Epoch 49/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -7.8124 - g_loss: 20.4597
# Epoch 50/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.7258 - g_loss: 27.6420
# Epoch 51/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.7179 - g_loss: 27.1549
# Epoch 52/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.6230 - g_loss: 20.6289
# Epoch 53/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.5005 - g_loss: 18.2109
# Epoch 54/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.3438 - g_loss: 16.0275
# Epoch 55/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.4199 - g_loss: 8.0327
# Epoch 56/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.3799 - g_loss: 18.8094
# Epoch 57/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -7.4204 - g_loss: 17.3911
# Epoch 58/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -7.1708 - g_loss: 16.8469
# Epoch 59/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -7.4740 - g_loss: 0.2046
# Epoch 60/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.3857 - g_loss: 2.7349
# Epoch 61/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -6.9579 - g_loss: 19.9022
# Epoch 62/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -7.3831 - g_loss: 6.9164
# Epoch 63/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -7.1236 - g_loss: 21.7731
# Epoch 64/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.1576 - g_loss: 21.6828
# Epoch 65/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.2141 - g_loss: 19.7000
# Epoch 66/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.1462 - g_loss: 9.2777
# Epoch 67/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -7.0240 - g_loss: 15.0860
# Epoch 68/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -7.1554 - g_loss: 15.9509
# Epoch 69/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.9143 - g_loss: 11.3328
# Epoch 70/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.6727 - g_loss: 15.1322
# Epoch 71/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.9607 - g_loss: 15.4595
# Epoch 72/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.6762 - g_loss: 13.3451
# Epoch 73/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -6.7355 - g_loss: 9.0348
# Epoch 74/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -6.5558 - g_loss: 13.4365
# Epoch 75/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -6.6525 - g_loss: 15.2611
# Epoch 76/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.8466 - g_loss: 7.1070
# Epoch 77/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.4432 - g_loss: 17.1837
# Epoch 78/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.6708 - g_loss: 6.2613
# Epoch 79/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.3957 - g_loss: 3.9927
# Epoch 80/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.3001 - g_loss: 5.7444
# Epoch 81/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.2997 - g_loss: 13.3002
# Epoch 82/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.2212 - g_loss: 12.1004
# Epoch 83/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.4053 - g_loss: 11.1419
# Epoch 84/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.1786 - g_loss: 4.4009
# Epoch 85/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -6.3222 - g_loss: 10.0953
# Epoch 86/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -6.1877 - g_loss: 7.7211
# Epoch 87/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -6.3106 - g_loss: 1.0439
# Epoch 88/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -6.2618 - g_loss: 4.6210
# Epoch 89/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.9586 - g_loss: 7.9681
# Epoch 90/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.2239 - g_loss: 3.9865
# Epoch 91/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.9215 - g_loss: 9.0781
# Epoch 92/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.1317 - g_loss: 11.5975
# Epoch 93/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.8674 - g_loss: 11.6055
# Epoch 94/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -6.0353 - g_loss: 7.3542
# Epoch 95/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.0440 - g_loss: 6.2595
# Epoch 96/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.8272 - g_loss: 8.0661
# Epoch 97/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.1028 - g_loss: 7.6213
# Epoch 98/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.0301 - g_loss: 5.4888
# Epoch 99/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.9543 - g_loss: 6.7525
# Epoch 100/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -6.2373 - g_loss: 7.6351
# Epoch 101/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.7894 - g_loss: 11.5241
# Epoch 102/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.8506 - g_loss: 10.4039
# Epoch 103/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.9692 - g_loss: 8.4481
# Epoch 104/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.8952 - g_loss: 8.6578
# Epoch 105/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.9836 - g_loss: 15.9147
# Epoch 106/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.7515 - g_loss: 5.1511
# Epoch 107/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.1390 - g_loss: 6.5047
# Epoch 108/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.7201 - g_loss: 6.6296
# Epoch 109/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.7077 - g_loss: 8.4747
# Epoch 110/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.9529 - g_loss: 8.0754
# Epoch 111/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.8554 - g_loss: 3.7833
# Epoch 112/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -6.0921 - g_loss: 5.2281
# Epoch 113/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.9964 - g_loss: 6.5608
# Epoch 114/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.5477 - g_loss: -0.8303
# Epoch 115/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.6796 - g_loss: 3.4645
# Epoch 116/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.5760 - g_loss: 2.1917
# Epoch 117/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.9063 - g_loss: 1.8894
# Epoch 118/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.7484 - g_loss: -0.4554
# Epoch 119/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -5.4895 - g_loss: 2.8491
# Epoch 120/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -5.5536 - g_loss: 5.6125
# Epoch 121/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -5.4885 - g_loss: 5.0477
# Epoch 122/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -5.5741 - g_loss: 4.3931
# Epoch 123/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.6755 - g_loss: 4.8899
# Epoch 124/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -5.5598 - g_loss: 8.0429
# Epoch 125/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.5515 - g_loss: 7.6944
# Epoch 126/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.1649 - g_loss: 3.8531
# Epoch 127/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.4563 - g_loss: 2.5939
# Epoch 128/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.4763 - g_loss: 3.5436
# Epoch 129/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.6276 - g_loss: 2.7049
# Epoch 130/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.5410 - g_loss: 1.3759
# Epoch 131/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.5142 - g_loss: 2.2290
# Epoch 132/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.6367 - g_loss: 1.4652
# Epoch 133/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.6828 - g_loss: 5.3297
# Epoch 134/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.8286 - g_loss: 8.3327
# Epoch 135/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.1626 - g_loss: 0.4504
# Epoch 136/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.4766 - g_loss: 0.0121
# Epoch 137/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.2010 - g_loss: 0.2796
# Epoch 138/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.2420 - g_loss: 2.4139
# Epoch 139/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.3060 - g_loss: 0.6131
# Epoch 140/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.3863 - g_loss: -0.6443
# Epoch 141/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.3586 - g_loss: 0.5450
# Epoch 142/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -5.5380 - g_loss: 1.7759
# Epoch 143/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -5.3920 - g_loss: 2.8441
# Epoch 144/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -5.2203 - g_loss: 0.0996
# Epoch 145/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -5.3424 - g_loss: 3.5004
# Epoch 146/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.1771 - g_loss: 1.4563
# Epoch 147/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.3444 - g_loss: 2.4172
# Epoch 148/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.4738 - g_loss: 4.4491
# Epoch 149/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.0913 - g_loss: 1.8109
# Epoch 150/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.3354 - g_loss: -0.4196
# Epoch 151/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.0760 - g_loss: 2.6419
# Epoch 152/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.2688 - g_loss: 5.2090
# Epoch 153/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.3490 - g_loss: 1.5076
# Epoch 154/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.1368 - g_loss: 5.9014
# Epoch 155/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.0841 - g_loss: 0.0990
# Epoch 156/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.0831 - g_loss: -1.3318
# Epoch 157/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.1431 - g_loss: -1.7704
# Epoch 158/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.2326 - g_loss: 1.2767
# Epoch 159/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.2969 - g_loss: -0.3920
# Epoch 160/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9660 - g_loss: 0.2990
# Epoch 161/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.1840 - g_loss: 2.4000
# Epoch 162/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.1478 - g_loss: 2.7368
# Epoch 163/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.4432 - g_loss: 0.3989
# Epoch 164/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.5049 - g_loss: 3.1997
# Epoch 165/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.2633 - g_loss: 1.6145
# Epoch 166/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.0155 - g_loss: 2.5915
# Epoch 167/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.9919 - g_loss: -3.5630
# Epoch 168/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.4106 - g_loss: -0.3950
# Epoch 169/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8814 - g_loss: -0.0130
# Epoch 170/500
# 39/39 [==============================] - 32s 820ms/step - d_loss: -4.9103 - g_loss: -1.1273
# Epoch 171/500
# 39/39 [==============================] - 32s 831ms/step - d_loss: -4.9542 - g_loss: -1.8022
# Epoch 172/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.1299 - g_loss: -1.0050
# Epoch 173/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.1184 - g_loss: 9.6601
# Epoch 174/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.0942 - g_loss: 2.8505
# Epoch 175/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.1836 - g_loss: 2.9418
# Epoch 176/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9555 - g_loss: 5.2567
# Epoch 177/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8201 - g_loss: 3.2095
# Epoch 178/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.0179 - g_loss: -1.4463
# Epoch 179/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.9086 - g_loss: -0.8746
# Epoch 180/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9266 - g_loss: -3.7804
# Epoch 181/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8077 - g_loss: -0.5221
# Epoch 182/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.1509 - g_loss: -0.5041
# Epoch 183/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8505 - g_loss: -8.6202
# Epoch 184/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6836 - g_loss: -1.8946
# Epoch 185/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9278 - g_loss: -0.3384
# Epoch 186/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8782 - g_loss: 0.7954
# Epoch 187/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.7477 - g_loss: -7.9760
# Epoch 188/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.9189 - g_loss: -6.6345
# Epoch 189/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.0618 - g_loss: 2.6780
# Epoch 190/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.3037 - g_loss: -5.4868
# Epoch 191/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.0334 - g_loss: -10.5110
# Epoch 192/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.5024 - g_loss: -5.4636
# Epoch 193/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6780 - g_loss: -6.3583
# Epoch 194/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8283 - g_loss: -2.5642
# Epoch 195/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8037 - g_loss: 1.3955
# Epoch 196/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -5.0166 - g_loss: -1.0643
# Epoch 197/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.0019 - g_loss: -1.4432
# Epoch 198/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -4.9292 - g_loss: -1.6981
# Epoch 199/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -4.7749 - g_loss: -3.3804
# Epoch 200/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.7554 - g_loss: -1.8865
# Epoch 201/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8280 - g_loss: -2.1618
# Epoch 202/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.6351 - g_loss: -2.9236
# Epoch 203/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7793 - g_loss: 0.4107
# Epoch 204/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.0145 - g_loss: -0.7472
# Epoch 205/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7472 - g_loss: -2.7438
# Epoch 206/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.0508 - g_loss: 6.2499
# Epoch 207/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.9240 - g_loss: 2.0630
# Epoch 208/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.9266 - g_loss: 0.7020
# Epoch 209/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9635 - g_loss: 1.1325
# Epoch 210/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7902 - g_loss: 1.8492
# Epoch 211/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8940 - g_loss: 2.8650
# Epoch 212/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7818 - g_loss: -0.6535
# Epoch 213/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5814 - g_loss: -0.7892
# Epoch 214/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7109 - g_loss: 0.5209
# Epoch 215/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9524 - g_loss: 1.0048
# Epoch 216/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.2157 - g_loss: 3.1548
# Epoch 217/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5899 - g_loss: 0.9205
# Epoch 218/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.9137 - g_loss: -1.7952
# Epoch 219/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7877 - g_loss: -3.9663
# Epoch 220/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7379 - g_loss: -4.1302
# Epoch 221/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.0096 - g_loss: -2.2831
# Epoch 222/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.1808 - g_loss: -2.9494
# Epoch 223/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5459 - g_loss: -1.8237
# Epoch 224/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5922 - g_loss: 3.1949
# Epoch 225/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8880 - g_loss: 3.8323
# Epoch 226/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7133 - g_loss: -2.1957
# Epoch 227/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.7140 - g_loss: -1.2214
# Epoch 228/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9204 - g_loss: -0.6405
# Epoch 229/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6058 - g_loss: -0.6978
# Epoch 230/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7711 - g_loss: 2.3506
# Epoch 231/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.7354 - g_loss: 2.1285
# Epoch 232/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.7608 - g_loss: 3.3606
# Epoch 233/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -4.6226 - g_loss: -1.9181
# Epoch 234/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -5.0669 - g_loss: -4.1359
# Epoch 235/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5280 - g_loss: -5.4393
# Epoch 236/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7625 - g_loss: 1.2107
# Epoch 237/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.6725 - g_loss: 0.1563
# Epoch 238/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8529 - g_loss: -1.0736
# Epoch 239/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8102 - g_loss: -0.7561
# Epoch 240/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5966 - g_loss: -0.8431
# Epoch 241/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.6972 - g_loss: -0.6173
# Epoch 242/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8294 - g_loss: -0.3328
# Epoch 243/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5530 - g_loss: 1.1609
# Epoch 244/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6519 - g_loss: -1.1408
# Epoch 245/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8442 - g_loss: -3.4418
# Epoch 246/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8240 - g_loss: -3.4440
# Epoch 247/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.7800 - g_loss: -3.6320
# Epoch 248/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8581 - g_loss: 0.8405
# Epoch 249/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7202 - g_loss: -1.2503
# Epoch 250/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9009 - g_loss: -0.9313
# Epoch 251/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9568 - g_loss: 1.8733
# Epoch 252/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9918 - g_loss: -3.2560
# Epoch 253/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7532 - g_loss: 3.0955
# Epoch 254/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5546 - g_loss: 0.0403
# Epoch 255/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.8192 - g_loss: -0.6710
# Epoch 256/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.6287 - g_loss: -0.1092
# Epoch 257/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4759 - g_loss: -2.1546
# Epoch 258/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5362 - g_loss: -4.2235
# Epoch 259/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.0379 - g_loss: -1.3765
# Epoch 260/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6176 - g_loss: -5.2016
# Epoch 261/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.7237 - g_loss: -2.2586
# Epoch 262/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4527 - g_loss: -1.4703
# Epoch 263/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.8329 - g_loss: -1.8305
# Epoch 264/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7151 - g_loss: -0.7270
# Epoch 265/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5005 - g_loss: -0.7574
# Epoch 266/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.0765 - g_loss: -3.4577
# Epoch 267/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4999 - g_loss: -2.6810
# Epoch 268/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7478 - g_loss: -4.3069
# Epoch 269/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6497 - g_loss: -0.8798
# Epoch 270/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7849 - g_loss: 0.2426
# Epoch 271/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9364 - g_loss: -1.7543
# Epoch 272/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7786 - g_loss: 2.4332
# Epoch 273/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9366 - g_loss: -0.8890
# Epoch 274/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8485 - g_loss: -8.3166
# Epoch 275/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8090 - g_loss: -5.0300
# Epoch 276/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5068 - g_loss: -0.1479
# Epoch 277/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8346 - g_loss: -4.2420
# Epoch 278/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6792 - g_loss: -5.4637
# Epoch 279/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6705 - g_loss: 2.3205
# Epoch 280/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.4328 - g_loss: -3.7380
# Epoch 281/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.9028 - g_loss: 1.3088
# Epoch 282/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7209 - g_loss: -0.3687
# Epoch 283/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -4.1879 - g_loss: -3.2142
# Epoch 284/500
# 39/39 [==============================] - 32s 820ms/step - d_loss: -4.6498 - g_loss: 0.3078
# Epoch 285/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4654 - g_loss: -2.0547
# Epoch 286/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6901 - g_loss: -4.5484
# Epoch 287/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.3235 - g_loss: -2.5339
# Epoch 288/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.6547 - g_loss: 2.8908
# Epoch 289/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8384 - g_loss: 3.1488
# Epoch 290/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.3558 - g_loss: 1.7364
# Epoch 291/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3598 - g_loss: -3.2719
# Epoch 292/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.3882 - g_loss: -4.3907
# Epoch 293/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.6167 - g_loss: -0.8777
# Epoch 294/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7163 - g_loss: 2.5637
# Epoch 295/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7491 - g_loss: 1.3612
# Epoch 296/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7305 - g_loss: -1.5395
# Epoch 297/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3104 - g_loss: -0.4119
# Epoch 298/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6376 - g_loss: -2.8708
# Epoch 299/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5032 - g_loss: -2.5204
# Epoch 300/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5248 - g_loss: -1.3718
# Epoch 301/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6299 - g_loss: -0.4812
# Epoch 302/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7907 - g_loss: -1.7951
# Epoch 303/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3038 - g_loss: -4.8665
# Epoch 304/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5760 - g_loss: -1.5906
# Epoch 305/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6514 - g_loss: 0.7326
# Epoch 306/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8667 - g_loss: -3.7478
# Epoch 307/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.1714 - g_loss: -2.7791
# Epoch 308/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.6986 - g_loss: -0.3448
# Epoch 309/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7691 - g_loss: -1.4303
# Epoch 310/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4360 - g_loss: -2.1769
# Epoch 311/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.6038 - g_loss: -1.5381
# Epoch 312/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -4.8154 - g_loss: 0.0630
# Epoch 313/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -4.5001 - g_loss: -0.5841
# Epoch 314/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5898 - g_loss: -3.3725
# Epoch 315/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4046 - g_loss: -0.8518
# Epoch 316/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5452 - g_loss: -1.4169
# Epoch 317/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7003 - g_loss: -2.3329
# Epoch 318/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.9413 - g_loss: -2.8229
# Epoch 319/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.3818 - g_loss: -4.6839
# Epoch 320/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6846 - g_loss: -4.6926
# Epoch 321/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8965 - g_loss: -4.4946
# Epoch 322/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3316 - g_loss: -0.8260
# Epoch 323/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4623 - g_loss: 0.6010
# Epoch 324/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.8494 - g_loss: -2.8038
# Epoch 325/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6067 - g_loss: -0.0340
# Epoch 326/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6222 - g_loss: 0.1123
# Epoch 327/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3593 - g_loss: -1.3135
# Epoch 328/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4472 - g_loss: -2.0333
# Epoch 329/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5144 - g_loss: -1.9026
# Epoch 330/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6183 - g_loss: -0.8881
# Epoch 331/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8202 - g_loss: -1.9243
# Epoch 332/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6010 - g_loss: -0.8785
# Epoch 333/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6461 - g_loss: 0.7050
# Epoch 334/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6088 - g_loss: 0.2385
# Epoch 335/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8057 - g_loss: -0.2576
# Epoch 336/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.6219 - g_loss: -0.8739
# Epoch 337/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6582 - g_loss: -0.9893
# Epoch 338/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5225 - g_loss: 0.9676
# Epoch 339/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6501 - g_loss: -2.5669
# Epoch 340/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.6895 - g_loss: -0.7040
# Epoch 341/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5634 - g_loss: 0.1150
# Epoch 342/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4113 - g_loss: -2.4027
# Epoch 343/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.6413 - g_loss: -2.8737
# Epoch 344/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.8037 - g_loss: -3.2169
# Epoch 345/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -4.7136 - g_loss: -3.0503
# Epoch 346/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7627 - g_loss: -3.4791
# Epoch 347/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7250 - g_loss: -5.1276
# Epoch 348/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8305 - g_loss: -3.4334
# Epoch 349/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7857 - g_loss: -7.1691
# Epoch 350/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4783 - g_loss: -8.6239
# Epoch 351/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7191 - g_loss: -4.7587
# Epoch 352/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4782 - g_loss: -0.7445
# Epoch 353/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4340 - g_loss: -1.8488
# Epoch 354/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4953 - g_loss: -3.1234
# Epoch 355/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7354 - g_loss: -2.5097
# Epoch 356/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7235 - g_loss: -0.7626
# Epoch 357/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7760 - g_loss: -1.5614
# Epoch 358/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5741 - g_loss: -1.1123
# Epoch 359/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -5.0091 - g_loss: -0.9059
# Epoch 360/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4867 - g_loss: -0.5188
# Epoch 361/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.2608 - g_loss: -1.0519
# Epoch 362/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4136 - g_loss: -0.4432
# Epoch 363/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7127 - g_loss: 0.9266
# Epoch 364/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4003 - g_loss: -2.1009
# Epoch 365/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7933 - g_loss: 0.6986
# Epoch 366/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6463 - g_loss: 1.3260
# Epoch 367/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5968 - g_loss: 0.8293
# Epoch 368/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.7793 - g_loss: -1.6061
# Epoch 369/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.6996 - g_loss: -3.6390
# Epoch 370/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.6829 - g_loss: 0.2718
# Epoch 371/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6859 - g_loss: 0.1044
# Epoch 372/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8619 - g_loss: 1.8533
# Epoch 373/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.2844 - g_loss: -4.5919
# Epoch 374/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -5.0292 - g_loss: -0.8056
# Epoch 375/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.2520 - g_loss: 2.6414
# Epoch 376/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7721 - g_loss: 2.3336
# Epoch 377/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.1188 - g_loss: 0.9166
# Epoch 378/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5245 - g_loss: -2.8714
# Epoch 379/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6778 - g_loss: -2.8110
# Epoch 380/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5499 - g_loss: -4.4410
# Epoch 381/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7843 - g_loss: -6.4083
# Epoch 382/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5353 - g_loss: -5.0197
# Epoch 383/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5572 - g_loss: -1.4232
# Epoch 384/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5688 - g_loss: 0.0642
# Epoch 385/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6920 - g_loss: -2.7593
# Epoch 386/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.6013 - g_loss: -3.6710
# Epoch 387/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.6240 - g_loss: -1.4033
# Epoch 388/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4572 - g_loss: -2.0282
# Epoch 389/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4262 - g_loss: -2.8968
# Epoch 390/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.8259 - g_loss: -2.9102
# Epoch 391/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9644 - g_loss: -0.1190
# Epoch 392/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.2075 - g_loss: 0.3590
# Epoch 393/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4083 - g_loss: -2.5906
# Epoch 394/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6571 - g_loss: -3.9409
# Epoch 395/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.6639 - g_loss: -2.6333
# Epoch 396/500
# 39/39 [==============================] - 32s 821ms/step - d_loss: -4.6214 - g_loss: -1.0628
# Epoch 397/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.2595 - g_loss: -1.1634
# Epoch 398/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9074 - g_loss: 0.4988
# Epoch 399/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5136 - g_loss: -1.0468
# Epoch 400/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6798 - g_loss: -1.7421
# Epoch 401/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3913 - g_loss: -1.6098
# Epoch 402/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8136 - g_loss: -3.2378
# Epoch 403/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7175 - g_loss: -1.2496
# Epoch 404/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7090 - g_loss: -1.7491
# Epoch 405/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8502 - g_loss: -1.5359
# Epoch 406/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.6134 - g_loss: -3.1898
# Epoch 407/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.9108 - g_loss: 1.9869
# Epoch 408/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.2501 - g_loss: -1.8757
# Epoch 409/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8625 - g_loss: -0.9038
# Epoch 410/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6325 - g_loss: -4.1404
# Epoch 411/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7249 - g_loss: -4.0079
# Epoch 412/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7755 - g_loss: -2.1230
# Epoch 413/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.0813 - g_loss: -0.2191
# Epoch 414/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7400 - g_loss: -1.4407
# Epoch 415/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5560 - g_loss: -0.0618
# Epoch 416/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7148 - g_loss: -3.5057
# Epoch 417/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4039 - g_loss: -2.2110
# Epoch 418/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7485 - g_loss: -1.4424
# Epoch 419/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3659 - g_loss: -4.2989
# Epoch 420/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8085 - g_loss: -4.2781
# Epoch 421/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.8928 - g_loss: -3.1081
# Epoch 422/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.9518 - g_loss: -2.3733
# Epoch 423/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -4.5815 - g_loss: -9.6604
# Epoch 424/500
# 39/39 [==============================] - 32s 819ms/step - d_loss: -4.8502 - g_loss: -5.3729
# Epoch 425/500
# 39/39 [==============================] - 32s 829ms/step - d_loss: -4.4558 - g_loss: -6.6575
# Epoch 426/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4566 - g_loss: -5.8841
# Epoch 427/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5380 - g_loss: -0.7798
# Epoch 428/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -5.3515 - g_loss: 2.8455
# Epoch 429/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.0928 - g_loss: 1.9775
# Epoch 430/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6746 - g_loss: -0.0032
# Epoch 431/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4110 - g_loss: 0.8322
# Epoch 432/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8521 - g_loss: -0.8184
# Epoch 433/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.3008 - g_loss: 2.7892
# Epoch 434/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4321 - g_loss: -3.3415
# Epoch 435/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4236 - g_loss: -1.7861
# Epoch 436/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5502 - g_loss: -0.1749
# Epoch 437/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.8458 - g_loss: 0.9704
# Epoch 438/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -5.0525 - g_loss: 3.4779
# Epoch 439/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4952 - g_loss: 1.5632
# Epoch 440/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3749 - g_loss: -2.1813
# Epoch 441/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4381 - g_loss: 0.5269
# Epoch 442/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7106 - g_loss: -3.5683
# Epoch 443/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6005 - g_loss: -4.1880
# Epoch 444/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3004 - g_loss: -3.5629
# Epoch 445/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5820 - g_loss: -4.8878
# Epoch 446/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.9789 - g_loss: -3.8996
# Epoch 447/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.6043 - g_loss: -2.0364
# Epoch 448/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4563 - g_loss: -1.6160
# Epoch 449/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.2928 - g_loss: -2.2229
# Epoch 450/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5011 - g_loss: -2.6664
# Epoch 451/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.6676 - g_loss: -4.3699
# Epoch 452/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.2898 - g_loss: -1.8973
# Epoch 453/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5232 - g_loss: -0.6780
# Epoch 454/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.6653 - g_loss: 0.2618
# Epoch 455/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.4249 - g_loss: -1.8402
# Epoch 456/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.5866 - g_loss: -2.8455
# Epoch 457/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.5482 - g_loss: -3.1152
# Epoch 458/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3824 - g_loss: -4.0423
# Epoch 459/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.5595 - g_loss: -1.9360
# Epoch 460/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.8442 - g_loss: 0.8577
# Epoch 461/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.3484 - g_loss: 1.1543
# Epoch 462/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4411 - g_loss: -0.8207
# Epoch 463/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4855 - g_loss: -0.7784
# Epoch 464/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5352 - g_loss: -2.1930
# Epoch 465/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4742 - g_loss: -2.9286
# Epoch 466/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7001 - g_loss: -0.3543
# Epoch 467/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5277 - g_loss: 0.5269
# Epoch 468/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5360 - g_loss: -0.2099
# Epoch 469/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.7126 - g_loss: 0.6084
# Epoch 470/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6192 - g_loss: -1.1376
# Epoch 471/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5371 - g_loss: -3.9909
# Epoch 472/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.8516 - g_loss: -4.0593
# Epoch 473/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.0517 - g_loss: -1.2600
# Epoch 474/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.6603 - g_loss: -2.3380
# Epoch 475/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.5844 - g_loss: -1.2918
# Epoch 476/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.7426 - g_loss: -5.1027
# Epoch 477/500
# 39/39 [==============================] - 32s 822ms/step - d_loss: -4.5899 - g_loss: -0.5610
# Epoch 478/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5630 - g_loss: 0.3742
# Epoch 479/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7784 - g_loss: -2.0240
# Epoch 480/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.4730 - g_loss: -2.4551
# Epoch 481/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.8613 - g_loss: -2.7239
# Epoch 482/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3082 - g_loss: -3.6494
# Epoch 483/500
# 39/39 [==============================] - 32s 823ms/step - d_loss: -4.7252 - g_loss: -2.4076
# Epoch 484/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.4395 - g_loss: -1.7596
# Epoch 485/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.5363 - g_loss: -1.3772
# Epoch 486/500
# 39/39 [==============================] - 32s 828ms/step - d_loss: -4.5221 - g_loss: -2.2276
# Epoch 487/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.5001 - g_loss: -3.6226
# Epoch 488/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4413 - g_loss: -2.4548
# Epoch 489/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.9189 - g_loss: 0.2325
# Epoch 490/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.6834 - g_loss: -1.0796
# Epoch 491/500
# 39/39 [==============================] - 32s 827ms/step - d_loss: -4.4891 - g_loss: -0.2084
# Epoch 492/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.5580 - g_loss: 2.3690
# Epoch 493/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.1760 - g_loss: -0.5103
# Epoch 494/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.3389 - g_loss: -1.3697
# Epoch 495/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4907 - g_loss: -3.8035
# Epoch 496/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4542 - g_loss: -3.8331
# Epoch 497/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.4888 - g_loss: -4.0696
# Epoch 498/500
# 39/39 [==============================] - 32s 824ms/step - d_loss: -4.7781 - g_loss: -4.3232
# Epoch 499/500
# 39/39 [==============================] - 32s 825ms/step - d_loss: -4.4572 - g_loss: -3.6901
# Epoch 500/500
# 39/39 [==============================] - 32s 826ms/step - d_loss: -4.7966 - g_loss: -2.7208

# %%
from IPython.display import Image, display

display(Image("generated_img_0_19.png"))
display(Image("generated_img_1_19.png"))
display(Image("generated_img_2_19.png"))

display(Image("generated_img_0_100.png"))
display(Image("generated_img_1_100.png"))
display(Image("generated_img_2_100.png"))

display(Image("generated_img_0_200.png"))
display(Image("generated_img_1_200.png"))
display(Image("generated_img_2_200.png"))

display(Image("generated_img_0_300.png"))
display(Image("generated_img_1_300.png"))
display(Image("generated_img_2_300.png"))

display(Image("generated_img_0_499.png"))
display(Image("generated_img_1_499.png"))
display(Image("generated_img_2_499.png"))
